# %%
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# %%
from utils.ssim import ssim

# %%
RAW_FILES_PATH = 'data/frames_raw'
REF_FILE = -1
FILES_SELECTED = [-2, -6, -18, -36]

# %%
files_s = sorted(glob.glob(os.path.join(RAW_FILES_PATH, '*')))
print(len(files_s))
# Out:
# 417

# %% [markdown]
# #### First channel

# %%
CHANNEL_NO = 0

# %%
image_s = []
for i in range(len(files_s)):
    filename = files_s[i]
    image = cv2.imread(filename)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_s.append(image)
image_s = np.array(image_s)
image_s = image_s[:, :, :, CHANNEL_NO].reshape(image_s.shape[0], image_s.shape[1], image_s.shape[2])
ref_image_s = image_s[REF_FILE]
image_s = image_s[FILES_SELECTED]
print(image_s.shape, ref_image_s.shape)
# Out:
# (4, 1000, 1000) (1000, 1000)

# %%
img1 = image_s[3]
img2 = ref_image_s
ssim_index, ssim_map = ssim(img1, img2)
print(ssim_index)

plt.imshow(img1, cmap='binary')
plt.show()
plt.imshow(img2, cmap='binary')
plt.show()
plt.imshow(ssim_map, cmap='binary')
plt.show()
# Out:
# 0.7840817676281603

# %%
for i in range(len(image_s)):
    img1 = image_s[i]
    img2 = ref_image_s
    ssim_index, ssim_map = ssim(img1, img2)
    print(ssim_index)
# Out:
# 0.9564415869490416
# 0.9126036120312838
# 0.8488607093803183
# 0.7840817676281603

# %% [markdown]
# #### Second channel

# %%
CHANNEL_NO = 1

image_s = []
for i in range(len(files_s)):
    filename = files_s[i]
    image = cv2.imread(filename)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_s.append(image)
image_s = np.array(image_s)
image_s = image_s[:, :, :, CHANNEL_NO].reshape(image_s.shape[0], image_s.shape[1], image_s.shape[2])
ref_image_s = image_s[REF_FILE]
image_s = image_s[FILES_SELECTED]
print(image_s.shape, ref_image_s.shape)
# Out:
# (4, 1000, 1000) (1000, 1000)

# %%
for i in range(len(image_s)):
    img1 = image_s[i]
    img2 = ref_image_s
    ssim_index, ssim_map = ssim(img1, img2)
    print(ssim_index)
# Out:
# 0.9601360159354693
# 0.9169530596508028
# 0.8530701445036375
# 0.7869794389969738

# %% [markdown]
# #### Third channel

# %%
CHANNEL_NO = 2

image_s = []
for i in range(len(files_s)):
    filename = files_s[i]
    image = cv2.imread(filename)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_s.append(image)
image_s = np.array(image_s)
image_s = image_s[:, :, :, CHANNEL_NO].reshape(image_s.shape[0], image_s.shape[1], image_s.shape[2])
ref_image_s = image_s[REF_FILE]
image_s = image_s[FILES_SELECTED]
print(image_s.shape, ref_image_s.shape)
# Out:
# (4, 1000, 1000) (1000, 1000)

# %%
for i in range(len(image_s)):
    img1 = image_s[i]
    img2 = ref_image_s
    ssim_index, ssim_map = ssim(img1, img2)
    print(ssim_index)
# Out:
# 0.9538894401863502
# 0.905944245582745
# 0.8413726315710478
# 0.7760711205206774
